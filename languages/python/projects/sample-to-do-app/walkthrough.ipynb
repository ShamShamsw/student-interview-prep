# %% [markdown]
# # Sample TODO app walkthrough (placeholder)
#
# This notebook is a short walkthrough that explains the project goals, shows starter usage, and demonstrates the final app briefly. Replace this placeholder with real walkthrough content.
